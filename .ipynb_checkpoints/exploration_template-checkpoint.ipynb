# %% [markdown]
# # PISA data exploration
# ## by Walaa Elnozahy
#
# ## Preliminary Wrangling
#
# PISA stands for "The Program for International Student Assessment" which is an international assessment that measures students who are 15-year-old. it aims to assess their skills such as reading, mathematics, and science literacy every 3 years. This data is gathered from gathered done for students who are about to end their education. they are assessing their level and skills  along with details about them to check how well prepared they are for life beyond school.
# > data should be containing all the details about students who went throught the survey and their skills and details

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# Here we are going to load the data to check and identify what does it contain
# > Load in your dataset and describe its properties through the questions below..

# %%
# load in the dataset into a pandas dataframeb
pisadef=pd.read_csv('pisadict2012.csv', encoding= 'latin1');

# %%
# General details about the data shape and composition
print(pisadef.shape)
print(pisadef.dtypes)
print(pisadef.head(10))
# Out:
# (635, 2)
# Unnamed: 0    object
# x             object
# dtype: object
#   Unnamed: 0                                                  x
# 0        CNT                           Country code 3-character
# 1   SUBNATIO  Adjudicated sub-region code 7-digit code (3-di...
# 2    STRATUM  Stratum ID 7-character (cnt + region ID + orig...
# 3       OECD                                       OECD country
# 4         NC                       National Centre 6-digit Code
# 5   SCHOOLID  School ID 7-digit (region ID + stratum ID + 3-...
# 6    STIDSTD                                         Student ID
# 7    ST01Q01                                International Grade
# 8    ST02Q01                           National Study Programme
# 9    ST03Q01                                      Birth - Month

# %%
pisa=pd.read_csv('pisa2012.csv', encoding= 'latin1')
# Out:
# c:\python38\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (15,16,17,21,22,23,24,25,26,30,31,36,37,45,65,123,155,156,157,158,159,160,161,162,163,164,165,166,167,168,169,170,171,284,285,286,287,288,289,290,291,292,293,294,295,296,297,298,299,300,301,302,303,307,308,309,310,311,312,313,314,315,316,317,318,319,320,321,322,323,324,325,326,327,328,329,330,331,332,333,334,335,336,337,338,339,340,341,342,343,344,345,346,347,348,349,350,351,352,353,354,355,356,357,376,377,378,379,380,381,382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,475) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
ps= pisa.head(10)
ps.to_csv('ps2012.csv', index = False)

# %%
# General details about the data shape and composition
print(pisa.shape)
print(pisa.dtypes)
print(pisa.head(10))
# Out:
# (485490, 636)
# Unnamed: 0      int64
# CNT            object
# SUBNATIO        int64
# STRATUM        object
# OECD           object
#                ...
# W_FSTR80      float64
# WVARSTRR        int64
# VAR_UNIT        int64
# SENWGT_STU    float64
# VER_STU        object
# Length: 636, dtype: object
#    Unnamed: 0      CNT  SUBNATIO  STRATUM      OECD       NC  SCHOOLID  \
# 0           1  Albania     80000  ALB0006  Non-OECD  Albania         1
# 1           2  Albania     80000  ALB0006  Non-OECD  Albania         1
# 2           3  Albania     80000  ALB0006  Non-OECD  Albania         1
# 3           4  Albania     80000  ALB0006  Non-OECD  Albania         1
# 4           5  Albania     80000  ALB0006  Non-OECD  Albania         1
# 5           6  Albania     80000  ALB0006  Non-OECD  Albania         1
# 6           7  Albania     80000  ALB0006  Non-OECD  Albania         1
# 7           8  Albania     80000  ALB0006  Non-OECD  Albania         1
# 8           9  Albania     80000  ALB0006  Non-OECD  Albania         1
# 9          10  Albania     80000  ALB0005  Non-OECD  Albania         2
#
#    STIDSTD  ST01Q01  ST02Q01  ...  W_FSTR75  W_FSTR76 W_FSTR77 W_FSTR78  \
# 0        1       10      1.0  ...   13.7954   13.9235  13.1249  13.1249
# 1        2       10      1.0  ...   13.7954   13.9235  13.1249  13.1249
# 2        3        9      1.0  ...   12.7307   12.7307  12.7307  12.7307
# 3        4        9      1.0  ...   12.7307   12.7307  12.7307  12.7307
# 4        5        9      1.0  ...   12.7307   12.7307  12.7307  12.7307
# 5        6        9      1.0  ...   12.7307   12.7307  12.7307  12.7307
# 6        7       10      1.0  ...   13.7954   13.9235  13.1249  13.1249
# 7        8       10      1.0  ...   14.4599   14.6374  15.8728  15.8728
# 8        9        9      1.0  ...   12.7307   12.7307  12.7307  12.7307
# 9       10       10      1.0  ...    3.3844   10.1533   3.3844  10.1533
#
#    W_FSTR79 W_FSTR80 WVARSTRR VAR_UNIT SENWGT_STU  VER_STU
# 0    4.3389  13.0829       19        1     0.2098  22NOV13
# 1    4.3389  13.0829       19        1     0.2098  22NOV13
# 2    4.2436  12.7307       19        1     0.1999  22NOV13
# 3    4.2436  12.7307       19        1     0.1999  22NOV13
# 4    4.2436  12.7307       19        1     0.1999  22NOV13
# 5    4.2436  12.7307       19        1     0.1999  22NOV13
# 6    4.3389  13.0829       19        1     0.2098  22NOV13
# 7    5.2248  15.2579       19        1     0.2322  22NOV13
# 8    4.2436  12.7307       19        1     0.1999  22NOV13
# 9   10.1533  10.1533       74        2     0.1594  22NOV13
#
# [10 rows x 636 columns]

# %%
# remove the not needed index
pisa = pisa.drop("Unnamed: 0",axis=1)
# preview data
print(pisa.head())
print(pisa.isnull().sum())
print(pisa.describe())
# check for dublicates 
print(sum(pisa.duplicated()))

# %% [markdown]
# Data sets has huge number of data. which is not totally needed and based on the info at hand we can select set of data that would be most useful to be used
# create a new dataset with these data only so we can work on it

# %%
#based on all of this we will work using these fields
df = pisa[['STIDSTD','GRADE','AGE','ST06Q01','ST03Q01','ST03Q02','ST04Q01','ST01Q01',
           'PV1MATH','PV2MATH','PV3MATH','PV4MATH','PV5MATH',
           'PV1READ','PV2READ','PV3READ','PV4READ','PV5READ',
           'PV1SCIE','PV2SCIE','PV3SCIE','PV4SCIE','PV5SCIE',
          'CNT', 'SUBNATIO', 'STRATUM','OECD','NC','SCHOOLID','ST11Q01','ST11Q02',
          'ST02Q01','ST08Q01','ST09Q01','ST115Q01','ST13Q01',
          'ST15Q01','ST17Q01','ST19Q01',
          'ST27Q01','ST27Q02','ST27Q03','ST27Q04','ST27Q05','ST28Q01',
          'OCOD1','OCOD2']].copy()

df.rename(columns={'GRADE':'grade','AGE':'age','ST03Q01':'birth_month','ST03Q02':'birth_year','ST04Q01':'gender',
                   'CNT':'countrycode', 'SUBNATIO':'subregion',
                   'OECD':'OECD_country','NC':'national_center_code','SCHOOLID':'school_id',
                   'ST11Q01':'At Home - Mother', 'ST11Q02':'At Home - Father',
                   'STIDSTD':'student_id','ST01Q01':'international_grade','ST02Q01':'study_programme',
                   
                   'ST08Q01':'late_for_school','ST09Q01':'skip_day','ST115Q01':'skip_classes',
                   'ST13Q01':'mother_highestdegree','ST15Q01':'mother_jobstatus',
                   'ST17Q01':'father_highestdegree','ST19Q01':'Father_jobstatus',
                   'ST27Q01':'num_mobiles','ST27Q02':'num_tvs','ST27Q03':'num_computers',
                   'ST27Q04':'num_cars','ST27Q05':'num_rooms','ST28Q01':'num_books',
                   'OCOD1':'mother_occupation',
                   'OCOD2':'father_occupation'}, inplace=True)

# %%
#save it in actual document 
df.to_csv('dffile.csv',index=False)

# %%
df=pd.read_csv('dffile.csv', encoding= 'latin1');

# %%
# General details about the data shape and composition
print(df.shape)
print(df.dtypes)
print(df.head(10))
# Out:
# (485490, 47)
# student_id                int64
# grade                   float64
# age                     float64
# ST06Q01                 float64
# birth_month               int64
# birth_year                int64
# gender                   object
# international_grade       int64
# PV1MATH                 float64
# PV2MATH                 float64
# PV3MATH                 float64
# PV4MATH                 float64
# PV5MATH                 float64
# PV1READ                 float64
# PV2READ                 float64
# PV3READ                 float64
# PV4READ                 float64
# PV5READ                 float64
# PV1SCIE                 float64
# PV2SCIE                 float64
# PV3SCIE                 float64
# PV4SCIE                 float64
# PV5SCIE                 float64
# countrycode              object
# subregion                 int64
# STRATUM                  object
# OECD_country             object
# national_center_code     object
# school_id                 int64
# At Home - Mother         object
# At Home - Father         object
# study_programme         float64
# late_for_school          object
# skip_day                 object
# skip_classes            float64
# mother_highestdegree     object
# mother_jobstatus         object
# father_highestdegree     object
# Father_jobstatus         object
# num_mobiles              object
# num_tvs                  object
# num_computers            object
# num_cars                 object
# num_rooms                object
# num_books                object
# mother_occupation        object
# father_occupation        object
# dtype: object
#    student_id  grade    age  ST06Q01  birth_month  birth_year  gender  \
# 0           1    0.0  16.17      6.0            2        1996  Female
# 1           2    0.0  16.17      7.0            2        1996  Female
# 2           3   -1.0  15.58      6.0            9        1996  Female
# 3           4   -1.0  15.67      6.0            8        1996  Female
# 4           5   -1.0  15.50      6.0           10        1996  Female
# 5           6   -1.0  15.58      6.0            9        1996  Female
# 6           7    0.0  16.08      6.0            3        1996  Female
# 7           8    0.0  15.83      6.0            6        1996    Male
# 8           9   -1.0  15.50      8.0           10        1996  Female
# 9          10    0.0  15.67      5.0            8        1996  Female
#
#    international_grade   PV1MATH   PV2MATH  ...   father_highestdegree  \
# 0                   10  406.8469  376.4683  ...      <ISCED level 3A>
# 1                   10  486.1427  464.3325  ...      <ISCED level 3A>
# 2                    9  533.2684  481.0796  ...      <ISCED level 3A>
# 3                    9  412.2215  498.6836  ...      <ISCED level 3A>
# 4                    9  381.9209  328.1742  ...  <ISCED level 3B, 3C>
# 5                    9  396.3312  354.2686  ...       <ISCED level 2>
# 6                   10  438.0823  540.1231  ...      <ISCED level 3A>
# 7                   10  576.5773  516.5992  ...      <ISCED level 3A>
# 8                    9  434.1097  353.1002  ...      <ISCED level 3A>
# 9                   10  463.6314  441.0422  ...      <ISCED level 3A>
#
#                      Father_jobstatus    num_mobiles        num_tvs  \
# 0         Working part-time <for pay>            Two            One
# 1        Working full-time <for pay>   Three or more  Three or more
# 2        Working full-time <for pay>   Three or more            Two
# 3        Working full-time <for pay>   Three or more            Two
# 4         Working part-time <for pay>            Two            One
# 5  Not working, but looking for a job            Two            Two
# 6  Other (e.g. home duties, retired)   Three or more  Three or more
# 7        Working full-time <for pay>             One            Two
# 8  Not working, but looking for a job  Three or more            Two
# 9         Working part-time <for pay>            Two            Two
#
#    num_computers  num_cars      num_rooms            num_books  \
# 0           None      None           None          0-10 books
# 1  Three or more       Two            Two       201-500 books
# 2            Two       One            Two  More than 500 books
# 3            One      None            One         11-25 books
# 4            Two      None            One       101-200 books
# 5           None       One            Two          0-10 books
# 6           None       Two            One          0-10 books
# 7            One       One            One        26-100 books
# 8            One       One  Three or more        26-100 books
# 9  Three or more      None           None         11-25 books
#
#                             mother_occupation  \
# 0                         Building architects
# 1  Tailors, dressmakers, furriers and hatters
# 2                                   Housewife
# 3                                   Housewife
# 4                                   Housewife
# 5                                     Missing
# 6                                   Housewife
# 7                                   Housewife
# 8                     Primary school teachers
# 9                Sales and marketing managers
#
#                                    father_occupation
# 0                            Primary school teachers
# 1                    Building construction labourers
# 2                    Bricklayers and related workers
# 3  Cleaners and helpers in offices, hotels and ot...
# 4                                         Economists
# 5                                              Cooks
# 6                      Stall and market salespersons
# 7                              General office clerks
# 8      Bakers, pastry-cooks and confectionery makers
# 9                                    Civil engineers
#
# [10 rows x 47 columns]

# %%
# let's review the final dataset to check for duplications
print(df.duplicated())
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 485485    False
# 485486    False
# 485487    False
# 485488    False
# 485489    False
# Length: 485490, dtype: bool

# %%
#check null values in the final dataset
print(df.isnull().sum())
# Out:
# student_id                  0
# grade                     873
# age                       116
# ST06Q01                 27496
# birth_month                 0
# birth_year                  0
# gender                      0
# international_grade         0
# PV1MATH                     0
# PV2MATH                     0
# PV3MATH                     0
# PV4MATH                     0
# PV5MATH                     0
# PV1READ                     0
# PV2READ                     0
# PV3READ                     0
# PV4READ                     0
# PV5READ                     0
# PV1SCIE                     0
# PV2SCIE                     0
# PV3SCIE                     0
# PV4SCIE                     0
# PV5SCIE                     0
# countrycode                 0
# subregion                   0
# STRATUM                     0
# OECD_country                0
# national_center_code        0
# school_id                   0
# At Home - Mother        24931
# At Home - Father        44454
# study_programme            52
# late_for_school          6347
# skip_day                 6359
# skip_classes             6221
# mother_highestdegree    27511
# mother_jobstatus        17739
# father_highestdegree    42229
# Father_jobstatus        34080
# num_mobiles              8411
# num_tvs                  8942
# num_computers           12031
# num_cars                12991
# num_rooms               15847
# num_books               11725
# mother_occupation        1603
# father_occupation        2554
# dtype: int64

# %% [markdown]
# based on these info we have few null value columns as the data is nearly 500,000 [485,490]
# so for the small number of nulls such as for age, grades we can either discard the data or set the null values to equal age average per each country/school
#
# but we prefer to discard these columns as it's not clear and we have enought data

# %%
#we take a copy of this data and start our final cleaning process 
df_copy=df.copy()
df_copy.dropna(subset=['grade','age'], inplace=True)
print(df_copy.info())
print(df_copy.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 484502 entries, 0 to 485489
# Data columns (total 47 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   student_id            484502 non-null  int64
#  1   grade                 484502 non-null  float64
#  2   age                   484502 non-null  float64
#  3   ST06Q01               457157 non-null  float64
#  4   birth_month           484502 non-null  int64
#  5   birth_year            484502 non-null  int64
#  6   gender                484502 non-null  object
#  7   international_grade   484502 non-null  int64
#  8   PV1MATH               484502 non-null  float64
#  9   PV2MATH               484502 non-null  float64
#  10  PV3MATH               484502 non-null  float64
#  11  PV4MATH               484502 non-null  float64
#  12  PV5MATH               484502 non-null  float64
#  13  PV1READ               484502 non-null  float64
#  14  PV2READ               484502 non-null  float64
#  15  PV3READ               484502 non-null  float64
#  16  PV4READ               484502 non-null  float64
#  17  PV5READ               484502 non-null  float64
#  18  PV1SCIE               484502 non-null  float64
#  19  PV2SCIE               484502 non-null  float64
#  20  PV3SCIE               484502 non-null  float64
#  21  PV4SCIE               484502 non-null  float64
#  22  PV5SCIE               484502 non-null  float64
#  23  countrycode           484502 non-null  object
#  24  subregion             484502 non-null  int64
#  25  STRATUM               484502 non-null  object
#  26  OECD_country          484502 non-null  object
#  27  national_center_code  484502 non-null  object
#  28  school_id             484502 non-null  int64
#  29  At Home - Mother      459652 non-null  object
#  30  At Home - Father      440188 non-null  object
#  31  study_programme       484450 non-null  float64
#  32  late_for_school       478191 non-null  object
#  33  skip_day              478182 non-null  object
#  34  skip_classes          478319 non-null  float64
#  35  mother_highestdegree  457128 non-null  object
#  36  mother_jobstatus      466850 non-null  object
#  37  father_highestdegree  442463 non-null  object
#  38  Father_jobstatus      450565 non-null  object
#  39  num_mobiles           476135 non-null  object
#  40  num_tvs               475611 non-null  object
#  41  num_computers         472533 non-null  object
#  42  num_cars              471581 non-null  object
#  43  num_rooms             468710 non-null  object
#  44  num_books             472841 non-null  object
#  45  mother_occupation     482910 non-null  object
#  46  father_occupation     481963 non-null  object
# dtypes: float64(20), int64(6), object(21)
# memory usage: 177.4+ MB
# None
# student_id                  0
# grade                       0
# age                         0
# ST06Q01                 27345
# birth_month                 0
# birth_year                  0
# gender                      0
# international_grade         0
# PV1MATH                     0
# PV2MATH                     0
# PV3MATH                     0
# PV4MATH                     0
# PV5MATH                     0
# PV1READ                     0
# PV2READ                     0
# PV3READ                     0
# PV4READ                     0
# PV5READ                     0
# PV1SCIE                     0
# PV2SCIE                     0
# PV3SCIE                     0
# PV4SCIE                     0
# PV5SCIE                     0
# countrycode                 0
# subregion                   0
# STRATUM                     0
# OECD_country                0
# national_center_code        0
# school_id                   0
# At Home - Mother        24850
# At Home - Father        44314
# study_programme            52
# late_for_school          6311
# skip_day                 6320
# skip_classes             6183
# mother_highestdegree    27374
# mother_jobstatus        17652
# father_highestdegree    42039
# Father_jobstatus        33937
# num_mobiles              8367
# num_tvs                  8891
# num_computers           11969
# num_cars                12921
# num_rooms               15792
# num_books               11661
# mother_occupation        1592
# father_occupation        2539
# dtype: int64

# %%
#print(df_copy.head(10))
#print(df_copy.info())
#so let's try to drop the null values
#df_copy.dropna(subset=['grade','age','At Home - Mother','At Home - Father','study_programme',
#                       'late_for_school','skip_day' ,'skip_classes','mother_highestdegree',
#                       'mother_jobstatus','father_highestdegree','Father_jobstatus',
#                       'num_mobiles','num_tvs','num_computers','num_cars' ,'num_rooms',
#                       'num_books' ,'mother_occupation','father_occupation'], inplace=True)

# %% [markdown]
# for now we are going to keep the fields that include null for the categorical points such as
# - At Home - Mother
# - At Home - Father
# - study_programme
# - late_for_school
# - skip_day
# - skip_classes
# - mother_highestdegree
# - mother_jobstatus
# - father_highestdegree
# - Father_jobstatus
# - num_mobiles
# - num_tvs
# - num_computers
# - num_cars
# - num_rooms
# - num_books
# - mother_occupation
# - father_occupation
#
# we may drop these fields or just replace it with new category that represent that it has no value so we can measure this

# %% [markdown]
# ### What is the structure of your dataset?
#
# > This data set consists of 636 column feature that shows detila about each student
# and 485,490 students data included these data includes many thing such as [age, grade, student ID, nationality, motnher and father education and job status, language used in their home, details about their level and wealth]
# some of the variables are numeric such as the age, weight. but most of the data are categorical such as the job status, cpuntries
#
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > I'm most interested in figuring out who are the top student's countries. what is the common feature for these students is is the number of hours they study.does perfrormance is based on gender, location, or student attitudes?
#
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# > the most important fields based on these data is grades per each student for math, scinece and read which will determine the students level. Along with other categorical indication for the student such as geneder, country of origin and the grade he is in.

# %%
#df_copy.iloc[::10]

# %%
# now it's important to check the correlation between the columns as we have too much details and we need to start anlysing 
#plt.figure(figsize=(20,20))
#sns.heatmap(df_copy.corr(), annot=True)

# %% [markdown]
# ## Univariate Exploration
#
# Now In this section, we are going to start investigation per each variable individually to check its details. you see unusual points or outliers, take a deeper look to clean things up
# and prepare yourself to look at relationships between variables.
# ### parameter 1: Students Countries

# %%
#number of students per each countries
df_copy.countrycode.value_counts()
# Out:
# Mexico                      33720
# Italy                       31073
# Spain                       25313
# Canada                      21544
# Brazil                      19204
#                             ...
# Florida (USA)                1896
# Perm(Russian Federation)     1761
# Massachusetts (USA)          1723
# Connecticut (USA)            1697
# Liechtenstein                 293
# Name: countrycode, Length: 68, dtype: int64

# %%
#list of all countires
base_color = sns.color_palette()[0] # To give the same colors to the bars
year= df_copy.countrycode.value_counts().index
fig_dims = (10,20)
fig = plt.subplots(figsize=fig_dims)
sns.countplot(y='countrycode',data = df_copy , color=base_color,order=year)
# Out:
# <AxesSubplot:xlabel='count', ylabel='countrycode'>

# %%
#top 10 Count
df_copy.countrycode.value_counts().index[:10]
# Out:
# Index(['Mexico', 'Italy', 'Spain', 'Canada', 'Brazil', 'Australia',
#        'United Kingdom', 'United Arab Emirates', 'Switzerland', 'Qatar'],
#       dtype='object')

# %%
#represent counts in boxplot 
plt.figure(figsize=(20,5))
sns.boxplot(df['countrycode'].value_counts())
sns.swarmplot(df['countrycode'].value_counts(), color='crimson')
plt.title('Student\'s country boxplot', size=30);
# Out:
# c:\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['countrycode'].describe()
# Out:
# count     485490
# unique        68
# top       Mexico
# freq       33806
# Name: countrycode, dtype: object

# %% [markdown]
# ### Conclusion for Students' countries
# **Based on the student's country the top 10 countries are**
# > ('Mexico', 'Italy', 'Spain', 'Canada', 'Brazil', 'Australia','United Kingdom', 'United Arab Emirates', 'Switzerland', 'Qatar')
#
# Most of the mean for the most of the countries is **5000**. there is many outliers specially for the top countries such as mexico that gets **33,806** and italy with **31,073**.
#
# =========
# ### parameter 2: Start leaning age

# %%
df.ST06Q01.hist()
# Out:
# <AxesSubplot:>

# %%
df.ST06Q01.describe()
# Out:
# count    457994.000000
# mean          6.148963
# std           0.970693
# min           4.000000
# 25%           6.000000
# 50%           6.000000
# 75%           7.000000
# max          16.000000
# Name: ST06Q01, dtype: float64

# %% [markdown]
# ### Conclusion for start learn age
# based on this most students started to learn on age 6, there is outliers which are small number of students who started to learn late on age of 16
#
# =========
# ### parameter 3: Student's age

# %%
sns.distplot(df_copy['age']);

# %%
age= df_copy.age.value_counts().index
fig_dims = (8,8)
fig = plt.subplots(figsize=fig_dims)
sns.countplot(y='age',data = df_copy , color=base_color,order=age)
# Out:
# <AxesSubplot:xlabel='count', ylabel='age'>

# %%
birthyear= df_copy.birth_month.value_counts().index
fig_dims = (8,8)
fig = plt.subplots(figsize=fig_dims)
sns.countplot(y='birth_month',data = df_copy , color='crimson',order=birthyear)
# Out:
# <AxesSubplot:xlabel='count', ylabel='birth_month'>

# %%
print (age.min(), ' and maximum of', age.max())
print ('number of students per each age:\n', df_copy.age.value_counts())
print('\n',df['age'].describe())
# Out:
# 15.17  and maximum of 16.33
# number of students per each age:
#  15.58    42684
# 15.67    42263
# 15.75    41585
# 15.83    41315
# 15.92    41016
# 16.00    40982
# 15.42    40367
# 15.50    40219
# 16.08    39243
# 16.17    38293
# 15.33    28301
# 16.25    26078
# 15.25    11978
# 16.33    10177
# 15.17        1
# Name: age, dtype: int64
#
#  count    485374.000000
# mean         15.784283
# std           0.290221
# min          15.170000
# 25%          15.580000
# 50%          15.750000
# 75%          16.000000
# max          16.330000
# Name: age, dtype: float64

# %% [markdown]
# ### Conclusion for age
# there is no huge age gab between students as min age is 15.17  and maximum of 16.33
# Most students are between 15.5 and 16
# mean = 15.784283
#
# =========
# ### parameter 4: Gender

# %%
gender= df_copy.gender.value_counts().index
fig_dims = (4,4)
fig, (ax1,ax2) = plt.subplots(1,2, figsize=(12,4))  # 1 row, 2 columns
sns.countplot(x='gender',data = df_copy , color=base_color,order=gender,ax=ax2)
plt.title('STUDENTS GENDER');
ax1.pie(df_copy['gender'].value_counts(), labels=df_copy['gender'].value_counts().index,startangle=90,counterclock=False)
print('Male Students: ',df_copy['gender'].value_counts()['Male'],' which is: {:.4f}%'.format(df_copy['gender'].value_counts()['Male']/df_copy.shape[0]))
print('Female Students: ',df_copy['gender'].value_counts()['Female'],' which is:  {:.4f}%'.format(df_copy['gender'].value_counts()['Female']/df_copy.shape[0]))
# Out:
# Male Students:  239809  which is: 0.4950%
# Female Students:  244693  which is:  0.5050%

# %% [markdown]
# ### Conclusion for gender
# Seems to be not biased as the count of female and male are so similar almost divided in half Most
# Male Students:  239809  which is: 0.4950%
# Female Students:  244693  which is:  0.5050%
#
#
# =========
# ### parameter 5: students score in science, math and reading

# %%
#sns.boxplot(data=df_copy, x='PV3MATH', y='PV4MATH', color=base_color)
#}plt.xticks(rotation=15);
#fig, ax = plt.subplots(nrows=5, figsize = [10,8])
fig, ax= plt.subplots(nrows=5,ncols=3,figsize=[20,12])

mathvariables = ['PV1MATH', 'PV2MATH','PV3MATH', 'PV4MATH', 'PV5MATH']      
readvariables = ['PV1READ','PV2READ','PV3READ','PV4READ','PV5READ']
scievariables = ['PV1SCIE','PV2SCIE','PV3SCIE','PV4SCIE','PV5SCIE']
i=0 
for var in mathvariables:
    bins = np.arange(min(df_copy[var]), max(df_copy[var])+5, 5)
    ax[i,0].hist(data = df_copy, x = var, bins = bins)
    ax[i,0].set_xlabel('{} (mm)'.format(var))
    i+=1
        
r=0
for var in readvariables:
    bins = np.arange(min(df_copy[var]), max(df_copy[var])+5, 5)
    ax[r,1].hist(data = df_copy, x = var, bins = bins, color='crimson')
    ax[r,1].set_xlabel('{} (mm)'.format(var))
    r+=1
s=0   
for var in scievariables:
    bins = np.arange(min(df_copy[var]), max(df_copy[var])+5, 5)
    ax[s,2].hist(data = df_copy, x = var, bins = bins, color='green')
    ax[s,2].set_xlabel('{} (mm)'.format(var))
    s+=1
plt.show()

# %%
bins = np.arange(0, df_copy['PV3MATH'].max()+5, 5)
plt.hist(data = df_copy, x = 'PV3MATH', bins = bins);

# %%
print(df_copy['PV1READ'].describe())
print(df_copy['PV2READ'].describe())      
print(df_copy['PV3READ'].describe())
print(df_copy['PV4READ'].describe())
print(df_copy['PV5READ'].describe())
print(df_copy['PV1SCIE'].describe())      
print(df_copy['PV2SCIE'].describe())
print(df_copy['PV3SCIE'].describe())
print(df_copy['PV4SCIE'].describe())
print(df_copy['PV5SCIE'].describe())

# %%
Reading = df_copy.PV1READ.value_counts()
df_copy['average_read'] = df[['PV1READ', 'PV2READ','PV3READ','PV4READ','PV5READ']].mean(axis=1)
df_copy['average_science'] = df[['PV1SCIE', 'PV2SCIE','PV3SCIE','PV4SCIE','PV5SCIE']].mean(axis=1)
df_copy['average_math'] = df[['PV1MATH', 'PV2MATH','PV3MATH','PV4MATH','PV5MATH']].mean(axis=1)
df_copy['total_avg_score'] = df[['average_math', 'average_science','average_read']].mean(axis=1)

df_copy.head()
# Out:
#    student_id  grade    age  ST06Q01  birth_month  birth_year  gender  \
# 0           1    0.0  16.17      6.0            2        1996  Female
# 1           2    0.0  16.17      7.0            2        1996  Female
# 2           3   -1.0  15.58      6.0            9        1996  Female
# 3           4   -1.0  15.67      6.0            8        1996  Female
# 4           5   -1.0  15.50      6.0           10        1996  Female
#
#    international_grade   PV1MATH   PV2MATH  ...  num_computers  num_cars  \
# 0                   10  406.8469  376.4683  ...           None      None
# 1                   10  486.1427  464.3325  ...  Three or more       Two
# 2                    9  533.2684  481.0796  ...            Two       One
# 3                    9  412.2215  498.6836  ...            One      None
# 4                    9  381.9209  328.1742  ...            Two      None
#
#    num_rooms            num_books                           mother_occupation  \
# 0       None          0-10 books                          Building architects
# 1        Two       201-500 books   Tailors, dressmakers, furriers and hatters
# 2        Two  More than 500 books                                   Housewife
# 3        One         11-25 books                                    Housewife
# 4        One       101-200 books                                    Housewife
#
#                                    father_occupation  average_read  \
# 0                            Primary school teachers     261.01424
# 1                    Building construction labourers     384.68832
# 2                    Bricklayers and related workers     405.18154
# 3  Cleaners and helpers in offices, hotels and ot...     477.46376
# 4                                         Economists     256.01010
#
#    average_science  average_math  total_avg_score
# 0        371.91348     366.18634       333.038020
# 1        478.12382     470.56396       444.458700
# 2        486.60946     505.53824       465.776413
# 3        453.97240     449.45476       460.296973
# 4        367.15778     385.50398       336.223953
#
# [5 rows x 51 columns]

# %%
fig, ax= plt.subplots(nrows=3,figsize=[20,12])

variables = ['average_read','average_science','average_math']
i=0 
for var in variables:
    bins = np.arange(min(df_copy[var]), max(df_copy[var])+5, 5)
    ax[i].hist(data = df_copy, x = var, bins = bins)
    ax[i].set_xlabel('{} (mm)'.format(var))
    i+=1
    print("\033[1m" + var, ' details is \n' + "\033[0m",df_copy[var].describe())

plt.show()
# Out:
# average_read  details is
#  count    484502.000000
# mean        472.204057
# std          98.809524
# min           6.445400
# 25%         405.284780
# 50%         475.695560
# 75%         542.978755
# max         849.359740
# Name: average_read, dtype: float64
# average_science  details is
#  count    484502.000000
# mean        475.974808
# std          97.973556
# min          25.158540
# 25%         406.042500
# 50%         475.699360
# 75%         546.475200
# max         857.832900
# Name: average_science, dtype: float64
# average_math  details is
#  count    484502.000000
# mean        469.819151
# std         100.780691
# min          54.767080
# 25%         396.175420
# 50%         465.968200
# 75%         540.278860
# max         903.107960
# Name: average_math, dtype: float64

# %% [markdown]
# ### conclusion scores
# the scores seems balanced and the distribution takes the bill shape.
# scores for read, scinece and math is around 465 and 475 however seems like the math has the most outliers with top students who got 903

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > the scores are normally distributed, however as we have 5 levels for the scores. then I had to calculate the average for the math so we can use it directly. Also the countries seems to have outliers
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# > the age and gender had null values, that wasn't huge so I dropped these values to remove nulls. Also score, calculated the average score for each type [Scinece, reading and math]

# %% [markdown]
# ## Bivariate Exploration
#
# In this section we are going to start to check the relation between 2 vaiables in the system such as the age, gender and location with regard to the total average score

# %%
#list of all schools
base_color = sns.color_palette()[0] # To give the same colors to the bars
school_id= df_copy.school_id.value_counts().index[:10]
fig_dims = (5,5)
fig = plt.subplots(figsize=fig_dims)
sns.countplot(y='school_id',data = df_copy , color=base_color,order=school_id)
# Out:
# <AxesSubplot:xlabel='count', ylabel='school_id'>

# %%
# let's compare top countries vs. gender
year= df_copy.countrycode.value_counts().index[:10]
fig = plt.subplots(figsize=(8,8))
country_gender = sns.countplot(y=df.countrycode, hue=df.gender, data=df_copy,order=year)
country_gender.set_title("country VS gender")
plt.show()

# %%
df_75=df_copy.query('total_avg_score>=@df_copy.total_avg_score.quantile(.75)')
df_90=df_copy.query('total_avg_score>=@df_copy.total_avg_score.quantile(.90)')
df_95=df_copy.query('total_avg_score>=@df_copy.total_avg_score.quantile(.95)')
df_99=df_copy.query('total_avg_score>=@df_copy.total_avg_score.quantile(.99)')

percent=[75,90,95,99]

fig, ax=plt.subplots(nrows=2, ncols=2, figsize=(8,5))

ax=ax.flatten()
for i in range(4):
    plt.sca(ax[i])
    df=eval('df_'+str(percent[i]))
    plt.countplot(y=df.countrycode, hue=df.gender, data=df_copy,order=year)
    pie(df['gender'].value_counts(), labels=df['gender'].value_counts().index,startangle=90,counterclock=False,autopct='%.2f')
    plt.axis('square')
    plt.title('TOP '+ str(percent[i])+'th PERCENTILE BY GENDER')

# %%
fig, ax=plt.subplots(nrows=2, ncols=2, figsize=(18,10))
ax=ax.flatten()
for i in range(4):
    plt.sca(ax[i])
    df=eval('df_'+str(percent[i]))
    sns.countplot(y=df.countrycode,color=base_color,  data=df_copy,order=df['countrycode'].value_counts().index[:10])
    plt.title('TOP '+ str(percent[i])+'th PERCENTILE for score BY country')

# %%
fig, ax=plt.subplots(nrows=2, ncols=2, figsize=(18,10))

ax=ax.flatten()
for i in range(4):
    plt.sca(ax[i])
    df=eval('df_'+str(percent[i]))
    sns.countplot(y=df.school_id,color=base_color,  data=df_copy,order=df['school_id'].value_counts().index[:10])
    plt.title('TOP '+ str(percent[i])+'th PERCENTILE for score BY school')

# %%
sns.boxplot(data=df_copy,order=df['school_id'].value_counts().index[:10], x='school_id', y='total_avg_score', color=base_color)
plt.xticks(rotation=15);

# %%
School vs country 
schools = [48,18,66,150,130,2,71,53,114,59]

# %% [markdown]
# ### Conclusion
# Order of the top counteries changed based on the percentile level changed when the level increases the italy goes down in the order instead of being the first country. Same occurs for the ages

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > the top countires changes based on the percential level we are using
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > Your answer here!

# %% [markdown]
# ## Multivariate Exploration
#
# > Create plots of three or more variables to investigate your data even
# further. Make sure that your investigations are justified, and follow from
# your work in the previous sections.

# %%
g = sns.FacetGrid(data = df_copy, hue = 'gender', hue_order=['male', 'Female'], size = 5, aspect = 1.5)
g.map(sns.regplot, 'gender', 'total_avg_score', x_jitter = 0.04, fit_reg = False)
g.add_legend()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\python38\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# c:\python38\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# c:\python38\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# TypeError: can only concatenate str (not "float") to str
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-156-cc57c9f3085f> in <module>
#       1 g = sns.FacetGrid(data = df_copy, hue = 'gender', hue_order=['male', 'Female'], size = 5, aspect = 1.5)
# ----> 2 g.map(sns.regplot, 'gender', 'total_avg_score', x_jitter = 0.04, fit_reg = False)
#       3 g.add_legend()
#
# c:\python38\lib\site-packages\seaborn\axisgrid.py in map(self, func, *args, **kwargs)
#     682
#     683             # Draw the plot
# --> 684             self._facet_plot(func, ax, plot_args, kwargs)
#     685
#     686         # Finalize the annotations and layout
#
# c:\python38\lib\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     772                 plot_kwargs[key] = val
#     773             plot_args = []
# --> 774         func(*plot_args, **plot_kwargs)
#     775
#     776         # Sort out the supporting information
#
# c:\python38\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# c:\python38\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     833     scatter_kws["marker"] = marker
#     834     line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 835     plotter.plot(ax, scatter_kws, line_kws)
#     836     return ax
#     837
#
# c:\python38\lib\site-packages\seaborn\regression.py in plot(self, ax, scatter_kws, line_kws)
#     365         # Draw the constituent plots
#     366         if self.scatter:
# --> 367             self.scatterplot(ax, scatter_kws)
#     368
#     369         if self.fit_reg:
#
# c:\python38\lib\site-packages\seaborn\regression.py in scatterplot(self, ax, kws)
#     394                 kws.setdefault("alpha", .8)
#     395
# --> 396             x, y = self.scatter_data
#     397             ax.scatter(x, y, **kws)
#     398         else:
#
# c:\python38\lib\site-packages\seaborn\regression.py in scatter_data(self)
#     143             x = self.x
#     144         else:
# --> 145             x = self.x + np.random.uniform(-x_j, x_j, len(self.x))
#     146
#     147         y_j = self.y_jitter
#
# c:\python38\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# c:\python38\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     341         lvalues = extract_array(left, extract_numpy=True)
#     342         rvalues = extract_array(right, extract_numpy=True)
# --> 343         result = arithmetic_op(lvalues, rvalues, op)
#     344
#     345         return left._construct_result(result, name=res_name)
#
# c:\python38\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     188     else:
#     189         with np.errstate(all="ignore"):
# --> 190             res_values = na_arithmetic_op(lvalues, rvalues, op)
#     191
#     192     return res_values
#
# c:\python38\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     148             #  will handle complex numbers incorrectly, see GH#32047
#     149             raise
# --> 150         result = masked_arith_op(left, right, op)
#     151
#     152     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# c:\python38\lib\site-packages\pandas\core\ops\array_ops.py in masked_arith_op(x, y, op)
#      90         if mask.any():
#      91             with np.errstate(all="ignore"):
# ---> 92                 result[mask] = op(xrav[mask], yrav[mask])
#      93
#      94     else:
#
# TypeError: can only concatenate str (not "float") to str

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > Your answer here!
#
# ### Were there any interesting or surprising interactions between features?
#
# > Your answer here!

# %% [markdown]
# > At the end of your report, make sure that you export the notebook as an
# html file from the `File > Download as... > HTML` menu. Make sure you keep
# track of where the exported file goes, so you can put it in the same folder
# as this notebook for project submission. Also, make sure you remove all of
# the quote-formatted guide notes like this one before you finish your report!

# %% [markdown]
# print(pisa['VER_STU'].describe()) #date of creation and seems all rows has the same date
# print('==========')
# print(pisa['SENWGT_STU'].describe()) #Senate weight - sum of weight within the country is 1000
# print('==========')
# print(pisa['W_FSTUWT'].describe()) #FINAL STUDENT WEIGHT
# print('==========')
# print(pisa['WEALTH'].describe())
# print('==========')
# print(pisa['OUTHOURS'].describe()) #Out-of-School Study Time
# print('==========')
# print(pisa['OPENPS'].describe()) #Openness for Problem Solving
# print('==========')
# print(pisa['OCOD1'].describe())#	ISCO-08 Occupation code - Mother
# print('==========')
# print(pisa['OCOD2'].describe())#	ISCO-08 Occupation code - Father
# LMINS	Learning time (minutes per week)  - <test language>
# LANGN	Language at home (3-digit code)
# AGE	Age of student
# GRADE	Grade compared to modal grade in country
# ====
# df.rename(columns={'GRADE':'grade','AGE':'age','LANGN':'home_langcode','LMINS':'learning_time',
#                    'OPENPS':'problemsolving_open',
#                    'OUTHOURS':'outschool_study','CNT':'countrycode', 'SUBNATIO':'subregion',
#                    'STRATUM','OECD':'OECD_country','NC':'national_center_code','SCHOOLID':'school_id',
#                    'ST20Q01':'birth_country','ST20Q02':'mother_birth_country','ST20Q03':'father_birth_country',
#                    'ST25Q01':'home_language',
#                    'STIDSTD':'student_id','ST01Q01':'international_grade','ST02Q01':'study_programme',
#                    'ST03Q01':'birth_month','ST03Q02':'birth_year','ST04Q01':'gender',
#                    'ST08Q01':'late_for_school','ST09Q01':'skip_day','ST115Q01':'skip_classes',
#                    'ST13Q01':'mother_highestdegree','ST15Q01':'mother_jobstatus',
#                    'ST17Q01':'father_highestdegree','ST19Q01':'Father_jobstatus',
#                    'ST27Q01':'num_mobiles','ST27Q02':'num_tvs','ST27Q03':'num_computers',
#                    'ST27Q04':'num_cars','ST27Q05':'num_rooms','ST28Q01':'num_books',
#                    'EC05Q01': 'firstlang','EC06Q01': 'start_learn_at',
#                    'EC07Q01':'mother_language','EC07Q02':'father_language',
#                    'EC07Q03':'sibling_language','EC07Q04':'bf_language',
#                    'EC07Q05':'Schoolmates_language','OCOD1':'mother_occupation',
#                    'OCOD2':'father_occupation','W_FSTUWT':'final_weight','SENWGT_STU':'countryweight'}, inplace=True)
# =====
#
# CNT	Country code 3-character
# SUBNATIO	Adjudicated sub-region code 7-digit code (3-digit country code + region ID + stratum ID)
# STRATUM	Stratum ID 7-character (cnt + region ID + original stratum ID)
# OECD	OECD country
# NC	National Centre 6-digit Code
# SCHOOLID	School ID 7-digit (region ID + stratum ID + 3-digit school ID)
# STIDSTD	Student ID
# ST01Q01	International Grade
# ST02Q01	National Study Programme
# ST03Q01	Birth - Month
# ST03Q02	Birth -Year
# ST04Q01	Gender
# ST08Q01	Truancy - Late for School
# ST09Q01	Truancy - Skip whole school day
# ST115Q01	Truancy - Skip classes within school day
#
# ST13Q01	Mother<Highest Schooling>
# ST15Q01	Mother Current Job Status
# ST17Q01	Father<Highest Schooling>
# ST19Q01	Father Current Job Status
#
# ST20Q01	Country of Birth International - Self
# ST20Q02	Country of Birth International - Mother
# ST20Q03	Country of Birth International - Father
# ST25Q01	International Language at Home
#
# ST27Q01	How many - cellular phones
# ST27Q02	How many - televisions
# ST27Q03	How many - computers
# ST27Q04	How many - cars
# ST27Q05	How many - rooms bath or shower
# ST28Q01	How many books at home
#
# EC05Q01	First language learned
# EC06Q01	Age started learning <test language>
# EC07Q01	Language spoken - Mother
# EC07Q02	Language spoken - Father
# EC07Q03	Language spoken - Siblings
# EC07Q04	Language spoken - Best friend
# EC07Q05	Language spoken - Schoolmates

# %%
At Home - Mother
At Home - Father
mother_highestdegree
mother_jobstatus 
mother_occupation

father_highestdegree
Father_jobstatus
father_occupation

study_programme  
late_for_school   
skip_day      
skip_classes   
num_mobiles  
num_tvs 
num_computers 
num_cars      
num_rooms  
num_books

# %%
# now it's important to check the correlation between the columns as we have too much details and we need to start anlysing 
#lt.figure(figsize=(20,20))
#sns.heatmap(pisa.corr(), annot=True)

# %%
#international_grade= df_copy.international_grade.value_counts().index
#print(international_grade)
#fig_dims = (4,4)
#fig = plt.subplots(figsize=fig_dims)
#print('International Grade #: ',international_grade, 'percentage is',df_copy['international_grade'].value_counts(),' which is: {:.4f}%'.format(df_copy['international_grade'].value_counts()[var]/df_copy['international_grade'].value_counts()))
#print('Female Students: ',df_copy['gender'].value_counts()['Female'],' which is:  {:.4f}%'.format(df_copy['gender'].value_counts()['Female']/df_copy.shape[0]))
#sns.countplot(x='international_grade',data = df_copy , color=base_color,order=international_grade)

# %%
df = pisa[['STIDSTD','GRADE','AGE','ST06Q01','LANGN','LMINS','OPENPS','OUTHOURS',
          'CNT', 'SUBNATIO', 'STRATUM','OECD','NC','SCHOOLID',
          'ST20Q01','ST20Q02','ST20Q03','ST25Q01',
          'ST01Q01','ST02Q01','ST03Q01','ST03Q02',
          'ST04Q01','ST08Q01','ST09Q01','ST115Q01','ST13Q01',
          'ST15Q01','ST17Q01','ST19Q01',
          'ST27Q01','ST27Q02','ST27Q03','ST27Q04','ST27Q05','ST28Q01',
          'EC05Q01','EC06Q01','EC07Q01','EC07Q02','EC07Q03','EC07Q04','EC07Q05',
          'OCOD1','OCOD2','W_FSTUWT','SENWGT_STU']].copy()

df.rename(columns={'GRADE':'grade','AGE':'age','LANGN':'home_langcode','LMINS':'learning_time',
                   'OPENPS':'problemsolving_open','ST06Q01':'age2',
                   'OUTHOURS':'outschool_study','CNT':'countrycode', 'SUBNATIO':'subregion',
                   'OECD':'OECD_country','NC':'national_center_code','SCHOOLID':'school_id',
                   'ST20Q01':'birth_country','ST20Q02':'mother_birth_country','ST20Q03':'father_birth_country',
                   'ST25Q01':'home_language',
                   'STIDSTD':'student_id','ST01Q01':'international_grade','ST02Q01':'study_programme',
                   'ST03Q01':'birth_month','ST03Q02':'birth_year','ST04Q01':'gender',
                   'ST08Q01':'late_for_school','ST09Q01':'skip_day','ST115Q01':'skip_classes',
                   'ST13Q01':'mother_highestdegree','ST15Q01':'mother_jobstatus',
                   'ST17Q01':'father_highestdegree','ST19Q01':'Father_jobstatus',
                   'ST27Q01':'num_mobiles','ST27Q02':'num_tvs','ST27Q03':'num_computers',
                   'ST27Q04':'num_cars','ST27Q05':'num_rooms','ST28Q01':'num_books',
                   'EC05Q01': 'firstlang','EC06Q01': 'start_learn_at',
                   'EC07Q01':'mother_language','EC07Q02':'father_language',
                   'EC07Q03':'sibling_language','EC07Q04':'bf_language',
                   'EC07Q05':'Schoolmates_language','OCOD1':'mother_occupation',
                   'OCOD2':'father_occupation','W_FSTUWT':'final_weight','SENWGT_STU':'countryweight'}, inplace=True)
